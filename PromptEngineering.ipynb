# %% [markdown]
# <a href="https://colab.research.google.com/github/parimalrajsscet/DemoSamples/blob/master/PromptEngineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prompt - Engineering -- it is the skill of designing and writing effective instructions for the ai models.

# %%
#Prompt - question, query, input, instruction, command

# %% [markdown]
# AI Tools Cheat Sheet
#
# 1. ChatGPT
# - Best for learning concepts, coding help, brainstorming, and content writing.
# - Strong reasoning ability and excellent at explaining complex topics clearly.
#
# 2. Claude
# - Best for analyzing long documents, research papers, and summaries.
# - Can process very large text inputs and provides detailed analytical responses.
#
# 3. Gemini
# - Best for real-time information, research, and tasks connected to Google services.
# -Strong integration with the Google ecosystem and up-to-date web knowledge.
#
# 4. Perplexity AI
# - Best for research and fact-checking questions.
# - Provides answers with cited sources, making it useful for reliable information lookup.
#
# 5. GitHub Copilot
# - Best for coding assistance inside development environments.
# - Suggests code, completes functions, and helps developers write programs faster.
#
# 6. Midjourney
# - Best for generating artistic images and creative illustrations from text prompts.
# - Produces high-quality visuals with strong artistic styling.
#
# 7. DALL·E
# - Best for generating images from natural language descriptions.
# - Useful for visualizing ideas, concepts, and creative designs.
#
# 8. Canva
# - Best for creating presentations, posters, and social media designs.
# - AI-assisted templates make professional design easy for beginners.
#
# 9. Runway
# - Best for AI-generated videos and advanced video editing.
# - Allows creators to generate and edit videos using AI tools.
#
# 10. Pictory
# - Best for converting scripts or articles into videos automatically.
# - Ideal for social media videos and quick content creation.
#
# 11. ElevenLabs
# - Best for realistic AI voice generation and narration.
# - Creates natural-sounding voiceovers for audiobooks, videos, and podcasts.
#
# 12. Notion AI
# - Best for note-taking, documentation, and productivity workflows.
# - Integrates AI directly into workspace tools for writing and organizing ideas.
#
# 13. Grammarly
# - Best for grammar checking and improving writing quality.
# - Helps refine tone, clarity, and professionalism in written communication.
#
# 14. Jasper AI
# - Best for marketing copy, blogs, and promotional content.
# - Designed specifically for generating high-quality marketing and SEO content.
#
# 15. Synthesia
# - Best for creating AI avatar videos for training or presentations.
# - Generates videos with digital presenters without needing cameras or actors.
#
# 16. Replit Ghostwriter
# - Best for writing, debugging, and explaining code directly inside the Replit coding environment.
# - Helps developers quickly generate code, fix errors, and understand programming concepts while coding.
#
# 17. Humata AI
# - Best for asking questions about PDFs and research documents.
# - Allows users to upload documents and quickly extract summaries, answers, and key insights.
#
# 18. Gamma
# - Best for creating presentations, documents, and webpages automatically from prompts.
# - Generates structured slides and visual layouts quickly without manual design.
#
# 19. Socratic
# - Best for helping students understand homework and academic concepts.
# - Uses AI to explain problems step-by-step in subjects like math, science, and history.
#
# 20. Tome
# - Best for AI-generated storytelling and visual presentations.
# - Converts ideas or prompts into structured slide decks with visuals and narrative flow.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# linear regression

# using the prompt anatomy as reference write a prompt to get to know about linear regression

# %%
# Zero Shot Prompting

# explain gradient descent in simple terms.
# translate good morning to spanish

# %%
# Few Shot Prompting

# Classify the sentiment :
# text : I like this movie -- positive
# text : I don't like to eat brinjal -- negative
# text : Today the weather is good --?

# %%
# algo: linear regression -- supervised
# algo: decision tree -- supervised
# algo: k-means -- unsupervised

# classify:

# algo: dbscan
# algo: svm

# %%
# Chain of Thought Prompting

# math, statistics, reasoning

# A dataset has 100 samples.
# 70 belong to class A and 30 belong to class B.

# Calculate entropy step by step.

# %%
# Write a python code for logistic regression using the dataset based on weather circumstances to predict if it will rain or not today. Explain each step

# %%
# Role Prompting

# You are a machine learning professor.
# Explain overfitting and underfitting using practical examples.

# %%
# # Iterative Prompting

# explain Pca
# give a mathematical explanation
# give a python implementation

# %%
# Prompt Chaining

# Generate a dataset for a regression problem.
# Write a python code to train a linear regression on the given dataset.
# explain the model results.
# give some optimization techniques which can help get better results.
# apply ridge on the same data.
# explain the differences in the results.

# %%
# RTF - Role, task , format

# CRISPE - Capacity, Role, Insight, Statement, Personality, Experiment(constraint)

# Coast - context, objective, actions, scenario, task

# %% [markdown]
# COAST

# %%
# Context: Our company is a premium, small-batch coffee roaster that prides itself on a personal connection with our subscribers. We are known for our "Community First" approach.

# Objective: The goal is to turn a negative delivery error into a "wow" moment of customer recovery. We want Sarah to feel that her loyalty is valued and that we take full responsibility for her hosting stress.

# Actions: > 1. Express sincere empathy for the ruined brunch.
# 2. State clearly that a full refund has been processed.
# 3. Provide the discount code "BRUNCH-RESCUE" for 20% off the next three orders.
# 4. Assure her that the correct Light Roast is being overnighted to her immediately.

# Scenario: A long-time VIP customer named Sarah ordered a Light Roast for a brunch she is hosting today, but we accidentally sent a Dark Roast. She is upset because she has no coffee for her guests.

# Task: Write a high-priority apology email. It should be concise, humble, and warm. Ensure the subject line conveys that this is an urgent personal message from the founder.

# %% [markdown]
# CRISPE

# %%
# Capacity & Role: Act as a Senior Communications Director for a high-end, artisanal coffee roasting company that prides itself on a "customer-first" culture.

# Insight: One of our most loyal VIP customers, Sarah, received a Dark Roast instead of the Light Roast she ordered for a brunch she is hosting today. She is understandably stressed and disappointed because her event is ruined by our mistake.

# Statement: Write a personal apology email to Sarah. You must inform her that we have already issued a full refund, and as a gesture of goodwill, we are giving her a unique code (BRUNCH-RESCUE) for 20% off her next three orders.

# Personality: Your tone should be deeply empathetic, humble, and sophisticated. Avoid "corporate speak"—sound like a human who truly cares about her morning being ruined.

# Experiment/Constraint: Please provide the response in two variations: one that is short and direct, and one that is slightly more conversational. Ensure neither version exceeds 150 words.

# %% [markdown]
# RTF

# %%
# Role: You are a Senior Customer Success Manager at a high-end specialty coffee brand known for exceptional service.

# Task: Write an apology email to a loyal customer named Sarah who received a dark roast instead of the light roast she ordered for a brunch event. You must acknowledge the inconvenience, confirm a full refund has been issued, and provide a unique code for 20% off her next three orders to make things right.

# Format: A structured email with a compelling subject line, a warm opening, bulleted points for the compensation details, and a professional sign-off. The tone should be empathetic and humble.
